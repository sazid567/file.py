# %%
import pandas as pd
df = pd.read_excel(r'E:\newfile py\pivot.xlsx','Sheet2')
df
# Out:
#          day  dhaka  rajshahi  rangpur  sylhet
# 0     Monday     12        17       21      37
# 1    Tuesday     21        57       25      38
# 2  Wednesday     45        14       26      34
# 3   Thursday     24        12       28      39
# 4     Friday     22        15       29      31
# 5   Saturday     33        18       27      32

# %%
import numpy as np
pd.crosstab(df.day,df.rajshahi,aggfunc = None)
# Out:
# rajshahi   12  14  15  17  18  57
# day
# Friday      0   0   1   0   0   0
# Monday      0   0   0   1   0   0
# Saturday    0   0   0   0   1   0
# Thursday    1   0   0   0   0   0
# Tuesday     0   0   0   0   0   1
# Wednesday   0   1   0   0   0   0

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
weather_data = {
    'date' : ['01/11/2022','02/11/2022','03/14/2024'],
    'temperature' : [32,33,21],
    'windspeed' : [6,8,5],
    'event' : ['rain','sunny','snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#          date  temperature  windspeed  event
# 0  01/11/2022           32          6   rain
# 1  02/11/2022           33          8  sunny
# 2  03/14/2024           21          5   snow

# %%
type(df.date[0])
# Out:
# str

# %%
import pandas as pd
weather_data = {
    'date' : ['01/11/2022','02/11/2022','03/14/2024'],
    'temperature' : [32,33,21],
    'windspeed' : [6,8,5],
    'event' : ['rain','sunny','snow']
}
df = pd.DataFrame(weather_data)

# Convert 'date' column to datetime and set it as index
df['date'] = pd.to_datetime(df['date'])
df['temperature'] =df['temperature'].astype(int)
df.head()
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-11           32          6   rain
# 1 2022-02-11           33          8  sunny
# 2 2024-03-14           21          5   snow

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import pandas as pd
df = pd.read_csv(r'E:\newfile py\AAPL.csv',parse_dates=['Date'],index_col='Date')
df.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-10  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-04-11  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-04-12  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-04-13  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-04-14  164.589996  166.320007  163.820007  165.210007  164.332840
#
#               Volume
# Date
# 2023-04-10  47716900
# 2023-04-11  47644200
# 2023-04-12  50133100
# 2023-04-13  68445600
# 2023-04-14  49386500

# %%
df.index
# Out:
# DatetimeIndex(['2023-04-10', '2023-04-11', '2023-04-12', '2023-04-13',
#                '2023-04-14', '2023-04-17', '2023-04-18', '2023-04-19',
#                '2023-04-20', '2023-04-21',
#                ...
#                '2024-03-27', '2024-03-28', '2024-04-01', '2024-04-02',
#                '2024-04-03', '2024-04-04', '2024-04-05', '2024-04-08',
#                '2024-04-09', '2024-04-10'],
#               dtype='datetime64[ns]', name='Date', length=253, freq=None)

# %%
(df.loc['2024-03-27':'2024-04-10'])
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-27  170.410004  173.600006  170.110001  173.309998  173.309998
# 2024-03-28  171.750000  172.229996  170.509995  171.479996  171.479996
# 2024-04-01  171.190002  171.250000  169.479996  170.029999  170.029999
# 2024-04-02  169.080002  169.339996  168.229996  168.839996  168.839996
# 2024-04-03  168.789993  170.679993  168.580002  169.649994  169.649994
# 2024-04-04  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-04-05  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-04-08  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-04-09  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-04-10  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# Date
# 2024-03-27  60273300
# 2024-03-28  65672700
# 2024-04-01  46240500
# 2024-04-02  49329500
# 2024-04-03  47691700
# 2024-04-04  53704400
# ...

# %%
df['Close'].resample('Q').mean().plot(kind='bar')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13236\3274907328.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df['Close'].resample('Q').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df['Close'].plot()
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv(r'E:\newfile py\AAPL_csv.csv')
df.head(5)
# Out:
#          Open        High         Low       Close   Adj Close    Volume
# 0  161.419998  162.029999  160.080002  162.029999  161.169724  47716900
# 1  162.350006  162.360001  160.509995  160.800003  159.946259  47644200
# 2  161.220001  162.059998  159.779999  160.100006  159.249985  50133100
# 3  161.630005  165.800003  161.419998  165.559998  164.680969  68445600
# 4  164.589996  166.320007  163.820007  165.210007  164.332840  49386500

# %%
df_n = pd.date_range(start  = '07/01/2023',end = '06/19/2024',freq='B')

# %%
df_n
# Out:
# DatetimeIndex(['2023-07-03', '2023-07-04', '2023-07-05', '2023-07-06',
#                '2023-07-07', '2023-07-10', '2023-07-11', '2023-07-12',
#                '2023-07-13', '2023-07-14',
#                ...
#                '2024-06-06', '2024-06-07', '2024-06-10', '2024-06-11',
#                '2024-06-12', '2024-06-13', '2024-06-14', '2024-06-17',
#                '2024-06-18', '2024-06-19'],
#               dtype='datetime64[ns]', length=253, freq='B')

# %%
df.set_index(df_n,inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-03  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-07-04  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-07-05  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-07-06  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-07-07  164.589996  166.320007  163.820007  165.210007  164.332840
# ...                ...         ...         ...         ...         ...
# 2024-06-13  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-06-14  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-06-17  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-06-18  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-06-19  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-03  47716900
# 2023-07-04  47644200
# 2023-07-05  50133100
# 2023-07-06  68445600
# ...

# %%
df.loc['2023-07-07':'2024-06-13'].Close.mean()
# Out:
# 181.42595943265306

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-03  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-07-04  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-07-05  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-07-06  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-07-07  164.589996  166.320007  163.820007  165.210007  164.332840
# ...                ...         ...         ...         ...         ...
# 2024-06-13  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-06-14  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-06-17  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-06-18  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-06-19  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-03  47716900
# 2023-07-04  47644200
# 2023-07-05  50133100
# 2023-07-06  68445600
# ...

# %%
df.Close.plot()
# Out:
# <Axes: >

# %%
df.loc['2023-07-07':'2024-06-19']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-07  164.589996  166.320007  163.820007  165.210007  164.332840
# 2023-07-10  165.089996  165.389999  164.029999  165.229996  164.352737
# 2023-07-11  166.100006  167.410004  165.649994  166.470001  165.586166
# 2023-07-12  165.800003  168.160004  165.539993  167.630005  166.740005
# 2023-07-13  166.089996  167.869995  165.559998  166.649994  165.765198
# ...                ...         ...         ...         ...         ...
# 2024-06-13  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-06-14  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-06-17  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-06-18  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-06-19  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-07  49386500
# 2023-07-10  41516200
# 2023-07-11  49923000
# 2023-07-12  47720200
# ...

# %%
h = df.asfreq('CBME',method='pad')
h
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-31  172.479996  173.850006  172.110001  173.500000  172.578827
# 2023-08-31  181.500000  182.229996  180.630005  180.960007  180.248199
# 2023-09-29  189.679993  191.699997  188.470001  189.770004  189.023544
# 2023-10-31  177.320007  178.619995  176.550003  177.789993  177.329803
# 2023-11-30  176.509995  177.300003  173.979996  174.210007  173.759064
# 2023-12-29  180.070007  182.339996  179.039993  180.710007  180.242249
# 2024-01-31  187.699997  188.110001  186.300003  187.440002  187.201126
# 2024-02-29  198.020004  199.619995  196.160004  198.110001  197.857529
# 2024-03-29  181.270004  182.929993  180.300003  182.679993  182.447189
# 2024-04-30  183.419998  184.850006  181.669998  182.309998  182.309998
# 2024-05-31  177.050003  177.490005  170.839996  171.369995  171.369995
#
#                Volume
# 2023-07-31   55962800
# 2023-08-31   48870700
# 2023-09-29   60750200
# ...

# %%
h.loc['2023-07-03 04:00:00':'2023-07-03 04:00:00']
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
r = pd.date_range(start = '2023-07-31',periods=72,freq='B')
r
# Out:
# DatetimeIndex(['2023-07-31', '2023-08-01', '2023-08-02', '2023-08-03',
#                '2023-08-04', '2023-08-07', '2023-08-08', '2023-08-09',
#                '2023-08-10', '2023-08-11', '2023-08-14', '2023-08-15',
#                '2023-08-16', '2023-08-17', '2023-08-18', '2023-08-21',
#                '2023-08-22', '2023-08-23', '2023-08-24', '2023-08-25',
#                '2023-08-28', '2023-08-29', '2023-08-30', '2023-08-31',
#                '2023-09-01', '2023-09-04', '2023-09-05', '2023-09-06',
#                '2023-09-07', '2023-09-08', '2023-09-11', '2023-09-12',
#                '2023-09-13', '2023-09-14', '2023-09-15', '2023-09-18',
#                '2023-09-19', '2023-09-20', '2023-09-21', '2023-09-22',
#                '2023-09-25', '2023-09-26', '2023-09-27', '2023-09-28',
#                '2023-09-29', '2023-10-02', '2023-10-03', '2023-10-04',
#                '2023-10-05', '2023-10-06', '2023-10-09', '2023-10-10',
# ...

# %%
import numpy as np
ts =pd.Series(np.random.randint(1,10,len(r)),index = r)
ts.head(10)
# Out:
# 2023-07-31    7
# 2023-08-01    7
# 2023-08-02    3
# 2023-08-03    2
# 2023-08-04    8
# 2023-08-07    9
# 2023-08-08    9
# 2023-08-09    3
# 2023-08-10    2
# 2023-08-11    4
# Freq: B, dtype: int32

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

usb = CustomBusinessDay(calendar=USFederalHolidayCalendar())
usb

# %%
r= pd.date_range(start = '2023-07-07',end='2024-07-10',freq=usb)
r
# Out:
# DatetimeIndex(['2023-07-07', '2023-07-10', '2023-07-11', '2023-07-12',
#                '2023-07-13', '2023-07-14', '2023-07-17', '2023-07-18',
#                '2023-07-19', '2023-07-20',
#                ...
#                '2024-06-26', '2024-06-27', '2024-06-28', '2024-07-01',
#                '2024-07-02', '2024-07-03', '2024-07-05', '2024-07-08',
#                '2024-07-09', '2024-07-10'],
#               dtype='datetime64[ns]', length=253, freq='C')

# %%
df.set_index(r,inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-07  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-07-10  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-07-11  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-07-12  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-07-13  164.589996  166.320007  163.820007  165.210007  164.332840
# ...                ...         ...         ...         ...         ...
# 2024-07-03  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-07-05  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-07-08  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-07-09  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-07-10  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-07  47716900
# 2023-07-10  47644200
# 2023-07-11  50133100
# 2023-07-12  68445600
# ...

# %%
df.loc['2023-07-13':'2024-07-03']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-13  164.589996  166.320007  163.820007  165.210007  164.332840
# 2023-07-14  165.089996  165.389999  164.029999  165.229996  164.352737
# 2023-07-17  166.100006  167.410004  165.649994  166.470001  165.586166
# 2023-07-18  165.800003  168.160004  165.539993  167.630005  166.740005
# 2023-07-19  166.089996  167.869995  165.559998  166.649994  165.765198
# ...                ...         ...         ...         ...         ...
# 2024-06-27  171.750000  172.229996  170.509995  171.479996  171.479996
# 2024-06-28  171.190002  171.250000  169.479996  170.029999  170.029999
# 2024-07-01  169.080002  169.339996  168.229996  168.839996  168.839996
# 2024-07-02  168.789993  170.679993  168.580002  169.649994  169.649994
# 2024-07-03  170.289993  171.919998  168.820007  168.820007  168.820007
#
#               Volume
# 2023-07-13  49386500
# 2023-07-14  41516200
# 2023-07-17  49923000
# 2023-07-18  47720200
# ...

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
from pandas.tseries.offsets import Day

class myBirthDayCalendar(AbstractHolidayCalendar):
    """
US Federal Government Holiday Calendar based on rules specified by:
https://www.opm.gov/policy-data-oversight/pay-leave/federal-holidays/
    """

    rules = [
Holiday("birthday", month=3, day=8,observance=nearest_workday),
    ]
nyc = CustomBusinessDay(calendar =myBirthDayCalendar())
nyc

# %%
rr= pd.date_range(start = '2023-07-07',end='2024-06-26',freq=nyc)
rr
# Out:
# DatetimeIndex(['2023-07-07', '2023-07-10', '2023-07-11', '2023-07-12',
#                '2023-07-13', '2023-07-14', '2023-07-17', '2023-07-18',
#                '2023-07-19', '2023-07-20',
#                ...
#                '2024-06-13', '2024-06-14', '2024-06-17', '2024-06-18',
#                '2024-06-19', '2024-06-20', '2024-06-21', '2024-06-24',
#                '2024-06-25', '2024-06-26'],
#               dtype='datetime64[ns]', length=253, freq='C')

# %%
df.set_index(rr,inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-07  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-07-10  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-07-11  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-07-12  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-07-13  164.589996  166.320007  163.820007  165.210007  164.332840
# ...                ...         ...         ...         ...         ...
# 2024-06-20  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-06-21  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-06-24  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-06-25  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-06-26  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-07  47716900
# 2023-07-10  47644200
# 2023-07-11  50133100
# 2023-07-12  68445600
# ...

# %%
df.loc['2024/03/01':'2024/03/30']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2024-03-01  193.110001  193.490005  191.419998  193.179993  192.933807
# 2024-03-04  193.080002  194.720001  191.720001  194.710007  194.461868
# 2024-03-05  195.089996  198.000000  194.850006  197.960007  197.707718
# 2024-03-06  198.020004  199.619995  196.160004  198.110001  197.857529
# 2024-03-07  197.529999  198.399994  197.000000  197.570007  197.318222
# 2024-03-11  196.089996  196.630005  194.389999  195.889999  195.640350
# 2024-03-12  196.160004  196.949997  195.889999  196.940002  196.689026
# 2024-03-13  196.899994  197.679993  194.830002  194.830002  194.581711
# 2024-03-14  196.100006  197.080002  193.500000  194.679993  194.431885
# 2024-03-15  195.179993  195.410004  192.970001  193.600006  193.353287
# 2024-03-18  193.610001  193.889999  192.830002  193.050003  192.803986
# 2024-03-19  192.490005  193.500000  191.089996  193.149994  192.903839
# ...

# %%
b =CustomBusinessDay(weekmask = 'Sun Mon Tue Wed Thu')
df_1 = pd.date_range(start = '2023-07-07',end='2024-06-25',freq=b)
df_1
# Out:
# DatetimeIndex(['2023-07-09', '2023-07-10', '2023-07-11', '2023-07-12',
#                '2023-07-13', '2023-07-16', '2023-07-17', '2023-07-18',
#                '2023-07-19', '2023-07-20',
#                ...
#                '2024-06-12', '2024-06-13', '2024-06-16', '2024-06-17',
#                '2024-06-18', '2024-06-19', '2024-06-20', '2024-06-23',
#                '2024-06-24', '2024-06-25'],
#               dtype='datetime64[ns]', length=253, freq='C')

# %%
df.loc['2023-07-19':'2024-06-13']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-19  166.089996  167.869995  165.559998  166.649994  165.765198
# 2023-07-20  165.050003  166.449997  164.490005  165.020004  164.143860
# 2023-07-21  165.000000  165.600006  163.889999  165.330002  164.452209
# 2023-07-24  165.190002  166.309998  163.729996  163.770004  162.900482
# 2023-07-25  163.059998  165.279999  162.800003  163.759995  162.890533
# ...                ...         ...         ...         ...         ...
# 2024-06-07  177.050003  177.490005  170.839996  171.369995  171.369995
# 2024-06-10  171.759995  173.050003  170.059998  172.279999  172.279999
# 2024-06-11  170.570007  171.940002  169.449997  170.850006  170.850006
# 2024-06-12  170.000000  171.419998  169.580002  169.710007  169.710007
# 2024-06-13  170.410004  173.600006  170.110001  173.309998  173.309998
#
#                Volume
# 2023-07-19   52456400
# 2023-07-20   58337300
# 2023-07-21   41949600
# ...

# %%
df.loc['2024/04/01':'2024/04/29']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2024-04-01  184.350006  186.399994  183.919998  186.190002  185.952713
# 2024-04-02  186.539993  187.050003  183.619995  185.589996  185.353485
# 2024-04-03  186.059998  186.740005  185.190002  185.919998  185.683060
# 2024-04-04  182.160004  184.259995  180.929993  183.630005  183.395981
# 2024-04-05  181.270004  182.929993  180.300003  182.679993  182.447189
# 2024-04-08  186.089996  189.139999  185.830002  188.630005  188.389618
# 2024-04-09  189.330002  191.949997  188.820007  191.559998  191.315872
# 2024-04-10  192.300003  195.330002  192.259995  193.889999  193.642899
# 2024-04-11  195.020004  195.750000  193.830002  195.179993  194.931259
# 2024-04-12  195.419998  196.380005  194.339996  194.500000  194.252121
# 2024-04-15  195.220001  196.270004  193.110001  194.169998  193.922546
# 2024-04-16  194.270004  194.759995  191.940002  192.419998  192.174774
# ...

# %%
df_1
# Out:
# DatetimeIndex(['2023-07-09', '2023-07-10', '2023-07-11', '2023-07-12',
#                '2023-07-13', '2023-07-16', '2023-07-17', '2023-07-18',
#                '2023-07-19', '2023-07-20',
#                ...
#                '2024-06-12', '2024-06-13', '2024-06-16', '2024-06-17',
#                '2024-06-18', '2024-06-19', '2024-06-20', '2024-06-23',
#                '2024-06-24', '2024-06-25'],
#               dtype='datetime64[ns]', length=253, freq='C')

# %%
df.set_index(df_1,inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-07-09  161.419998  162.029999  160.080002  162.029999  161.169724
# 2023-07-10  162.350006  162.360001  160.509995  160.800003  159.946259
# 2023-07-11  161.220001  162.059998  159.779999  160.100006  159.249985
# 2023-07-12  161.630005  165.800003  161.419998  165.559998  164.680969
# 2023-07-13  164.589996  166.320007  163.820007  165.210007  164.332840
# ...                ...         ...         ...         ...         ...
# 2024-06-19  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-06-20  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-06-23  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-06-24  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-06-25  168.800003  169.089996  167.110001  167.779999  167.779999
#
#               Volume
# 2023-07-09  47716900
# 2023-07-10  47644200
# 2023-07-11  50133100
# 2023-07-12  68445600
# ...

# %%
df.loc['2024/04/01':'2024/04/29']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2024-04-01  186.539993  187.050003  183.619995  185.589996  185.353485
# 2024-04-02  186.059998  186.740005  185.190002  185.919998  185.683060
# 2024-04-03  182.160004  184.259995  180.929993  183.630005  183.395981
# 2024-04-04  181.270004  182.929993  180.300003  182.679993  182.447189
# 2024-04-07  186.089996  189.139999  185.830002  188.630005  188.389618
# 2024-04-08  189.330002  191.949997  188.820007  191.559998  191.315872
# 2024-04-09  192.300003  195.330002  192.259995  193.889999  193.642899
# 2024-04-10  195.020004  195.750000  193.830002  195.179993  194.931259
# 2024-04-11  195.419998  196.380005  194.339996  194.500000  194.252121
# 2024-04-14  195.220001  196.270004  193.110001  194.169998  193.922546
# 2024-04-15  194.270004  194.759995  191.940002  192.419998  192.174774
# 2024-04-16  192.009995  192.199997  189.580002  191.729996  191.485657
# ...
