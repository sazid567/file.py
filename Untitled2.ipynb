# %%
import pandas as pd
bd = pd.DataFrame({
    'city':['dhaka','rangpur','rajshahi'],
    'temperature':[40,35,30]
})
bd
# Out:
#        city  temperature
# 0     dhaka           40
# 1   rangpur           35
# 2  rajshahi           30

# %%
bd_2 = pd.DataFrame({
    'city':['sylhet','barishal','khulna'],
    'temperature':[30,29,25]
})
bd_2
# Out:
#        city  temperature
# 0    sylhet           30
# 1  barishal           29
# 2    khulna           25

# %%
df = pd.concat([bd,bd_2],ignore_index =False)
df
# Out:
#        city  temperature  windspeed
# 2     dhaka           40         20
# 1   rangpur           35         21
# 0  rajshahi           30         23
# 0    sylhet           30         54
# 1  barishal           29         55
# 2    khulna           25         56

# %%
pd.concat([bd,bd_2],keys=["d1","d2"])
# Out:
#           city  temperature
# d1 0     dhaka           40
#    1   rangpur           35
#    2  rajshahi           30
# d2 0    sylhet           30
#    1  barishal           29
#    2    khulna           25

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                  index=['cobra', 'viper', 'sidewinder'],
                  columns=['max_speed', 'shield'])
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df.loc['sidewinder']
# Out:
# max_speed    7
# shield       8
# Name: sidewinder, dtype: int64

# %%
import pandas as pd
bd_2 = pd.DataFrame({
    'city':['sylhet','barishal','khulna'],
    'temperature':[30,29,25],
    'windspeed':[54,55,56]
})
bd_2
# Out:
#        city  temperature  windspeed
# 0    sylhet           30         54
# 1  barishal           29         55
# 2    khulna           25         56

# %%
bd = pd.DataFrame({
    'city':['dhaka','rangpur','rajshahi'],
    'temperature':[40,35,30],
    'windspeed':[20,21,23]
},index=[2,1,0])
bd
# Out:
#        city  temperature  windspeed
# 2     dhaka           40         20
# 1   rangpur           35         21
# 0  rajshahi           30         23

# %%
df_1 = pd.concat([bd,bd_2],keys=['d1','d2'])
df_1
# Out:
#           city  temperature
# d1 0     dhaka           40
#    1   rangpur           35
#    2  rajshahi           30
# d2 0    sylhet           30
#    1  barishal           29
#    2    khulna           25

# %%
df_1.loc['d2']
# Out:
#        city  temperature
# 0    sylhet           30
# 1  barishal           29
# 2    khulna           25

# %%
df = pd.concat([bd,bd_2],axis=1)
df
# Out:
#        city  temperature  windspeed      city  temperature  windspeed
# 2     dhaka           40         20    khulna           25         56
# 1   rangpur           35         21  barishal           29         55
# 0  rajshahi           30         23    sylhet           30         54

# %%
d = df_1.loc['d1']
d
# Out:
#        city  temperature  windspeed
# 2     dhaka           40         20
# 1   rangpur           35         21
# 0  rajshahi           30         23

# %%
s = pd.Series(['humid','dry','rain'],name='event')
s
# Out:
# 0    humid
# 1      dry
# 2     rain
# Name: event, dtype: object

# %%
df=pd.concat([d,s],axis=1)
df
# Out:
#        city  temperature  windspeed  event
# 2     dhaka           40       20.0   rain
# 1   rangpur           35       21.0    dry
# 0  rajshahi           30       23.0  humid

# %%
df_new = pd.DataFrame({
    'city':['dhaka','rangpur','rajshahi','mymensingh'],
    'average windspeed':[20,21,22,23]
})
df_new
# Out:
#          city  average windspeed
# 0       dhaka                 20
# 1     rangpur                 21
# 2    rajshahi                 22
# 3  mymensingh                 23

# %%
df3 = pd.merge(df_new,df_1,on="city",how = "outer")
df3
# Out:
#          city  average windspeed  temperature
# 0    barishal                NaN         29.0
# 1       dhaka               20.0         40.0
# 2      khulna                NaN         25.0
# 3  mymensingh               23.0          NaN
# 4    rajshahi               22.0         30.0
# 5     rangpur               21.0         35.0
# 6      sylhet                NaN         30.0

# %%
pd.concat([bd,bd_2])
# Out:
#        city  temperature  windspeed
# 2     dhaka           40         20
# 1   rangpur           35         21
# 0  rajshahi           30         23
# 0    sylhet           30         54
# 1  barishal           29         55
# 2    khulna           25         56

# %%
df3.pivot(index='city',columns='temperature',values='windspeed'values=)
# Out:
#             average windspeed
# temperature               NaN 25.0 29.0  30.0  35.0  40.0
# city
# barishal                  NaN  NaN  NaN   NaN   NaN   NaN
# dhaka                     NaN  NaN  NaN   NaN   NaN  20.0
# khulna                    NaN  NaN  NaN   NaN   NaN   NaN
# mymensingh               23.0  NaN  NaN   NaN   NaN   NaN
# rajshahi                  NaN  NaN  NaN  22.0   NaN   NaN
# rangpur                   NaN  NaN  NaN   NaN  21.0   NaN
# sylhet                    NaN  NaN  NaN   NaN   NaN   NaN

# %%
df3.fillna(0)
# Out:
#          city  average windspeed  temperature
# 0    barishal                0.0         29.0
# 1       dhaka               20.0         40.0
# 2      khulna                0.0         25.0
# 3  mymensingh               23.0          0.0
# 4    rajshahi               22.0         30.0
# 5     rangpur               21.0         35.0
# 6      sylhet                0.0         30.0

# %%
df3.pivot_table(index='city',columns='average windspeed')
# Out:
#                   temperature             windspeed
# average windspeed        20.0  21.0  22.0      20.0  21.0  22.0
# city
# dhaka                    40.0   NaN   NaN      20.0   NaN   NaN
# rajshahi                  NaN   NaN  30.0       NaN   NaN  23.0
# rangpur                   NaN  35.0   NaN       NaN  21.0   NaN

# %%
import pandas as pd
df = pd.read_excel(r'E:\newfile py\pivot.xlsx','Sheet1',parse_dates=["date"])
df
# Out:
#         date     city  windspeed  temperature
# 0 2024-05-01    dhaka         20           20
# 1 2024-05-01    dhaka         19           22
# 2 2024-05-03  rangpur         54           19
# 3 2024-05-04   sylhet         50           15
# 4 2024-05-03  rangpur         78           15
# 5 2024-05-04   sylhet         80           16

# %%
type(df.city[0])
# Out:
# str

# %%
df.pivot(index='temperature',columns='city')
# Out:
#                   date                       windspeed
# city             dhaka    rangpur     sylhet     dhaka rangpur sylhet
# temperature
# 15                 NaT 2024-05-03 2024-05-04       NaN    78.0   50.0
# 16                 NaT        NaT 2024-05-04       NaN     NaN   80.0
# 19                 NaT 2024-05-03        NaT       NaN    54.0    NaN
# 20          2024-05-01        NaT        NaT      20.0     NaN    NaN
# 22          2024-05-01        NaT        NaT      19.0     NaN    NaN

# %%
df.pivot_table(index='city',columns='date',aggfunc='mean',margins=True)
# Out:
#                 temperature                                          \
# date    2024-05-01 00:00:00 2024-05-03 00:00:00 2024-05-04 00:00:00
# city
# dhaka                  21.0                 NaN                 NaN
# rangpur                 NaN                17.0                 NaN
# sylhet                  NaN                 NaN                15.5
# All                    21.0                17.0                15.5
#
#                              windspeed                      \
# date           All 2024-05-01 00:00:00 2024-05-03 00:00:00
# city
# dhaka    21.000000                19.5                 NaN
# rangpur  17.000000                 NaN                66.0
# sylhet   15.500000                 NaN                 NaN
# All      17.833333                19.5                66.0
#
#
# date    2024-05-04 00:00:00        All
# city
# dhaka                   NaN  19.500000
# rangpur                 NaN  66.000000
# sylhet                 65.0  65.000000
# ...

# %%
df.pivot_table(index=pd.Grouper(freq='ME',key='date'),columns='city')
# Out:
#            temperature                windspeed
# city             dhaka rangpur sylhet     dhaka rangpur sylhet
# date
# 2024-05-31        21.0    17.0   15.5      19.5    66.0   65.0

# %%
import pandas as pd
df = pd.read_excel(r'E:\newfile py\pivot.xlsx','Sheet2')
df
# Out:
#          day  dhaka  rajshahi  rangpur  sylhet
# 0     Monday     12        17       21      37
# 1    Tuesday     21        57       25      38
# 2  Wednesday     45        14       26      34
# 3   Thursday     24        12       28      39
# 4     Friday     22        15       29      31
# 5   Saturday     33        18       27      32

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#            dhaka  rajshahi  rangpur  sylhet
# day
# Monday        12        17       21      37
# Tuesday       21        57       25      38
# Wednesday     45        14       26      34
# Thursday      24        12       28      39
# Friday        22        15       29      31
# Saturday      33        18       27      32

# %%
df.reset_index('day')
# Out:
#          day  dhaka  rajshahi  rangpur  sylhet
# 0     Monday     12        17       21      37
# 1    Tuesday     21        57       25      38
# 2  Wednesday     45        14       26      34
# 3   Thursday     24        12       28      39
# 4     Friday     22        15       29      31
# 5   Saturday     33        18       27      32

# %%
df1=pd.melt(df,id_vars=['day'],var_name=None,value_name='temp',value_vars=['dhaka','rajshahi'])
df1
# Out:
#           day  variable  temp
# 0      Monday     dhaka    12
# 1     Tuesday     dhaka    21
# 2   Wednesday     dhaka    45
# 3    Thursday     dhaka    24
# 4      Friday     dhaka    22
# 5    Saturday     dhaka    33
# 6      Monday  rajshahi    17
# 7     Tuesday  rajshahi    57
# 8   Wednesday  rajshahi    14
# 9    Thursday  rajshahi    12
# 10     Friday  rajshahi    15
# 11   Saturday  rajshahi    18

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Administrator\OneDrive\Desktop\New Microsoft Excel Worksheet.xlsx','Sheet1',header=[0,1])
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_excel(r'C:\Users\Administrator\OneDrive\Desktop\New Microsoft Excel Worksheet.xlsx','Sheet1',header=[0,1])
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
df_stacked = df.stack(level=2)
df_stacked
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9196\373489331.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df.stack(level=2)
#                        Unnamed: 0_level_0 Unnamed: 1_level_0  \
#                        Unnamed: 0_level_1 Unnamed: 1_level_1
# 0 income statement                    NaN                NaN
#   price ratio                         NaN              price
# 1 Unnamed: 0_level_2              company                NaN
#   income statement                    NaN                NaN
#   price ratio                         NaN           facebook
# 2 Unnamed: 0_level_2  2024-06-05 00:00:00                NaN
#   income statement                    NaN                NaN
#   price ratio                         NaN                155
# ...

# %%
df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                             price                  \
#              company facebook google microsoft company facebook google
# 0         2024-06-05      NaT    NaT       NaT     NaN    155.0  955.0
# 1         2024-06-06      NaT    NaT       NaT     NaN    140.0  987.0
# 2         2024-06-07      NaT    NaT       NaT     NaN    200.0  963.0
# 3         2024-06-08      NaT    NaT       NaT     NaN    120.0  951.0
# 4         2024-06-09      NaT    NaT       NaT     NaN    220.0  941.0
# 5         2024-06-10      NaT    NaT       NaT     NaN    130.0  965.0
#
#             price to earning ratio(p/e)
#   microsoft                     company facebook google microsoft
# 0      65.0                         NaN    37.10  32.00     20.00
# 1      69.0                         NaN    36.98  31.30     25.00
# 2      62.0                         NaN    32.55  31.30     29.00
# 3      63.0                         NaN    31.28  35.00     23.00
# ...

# %%
>>> df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'three',
...                            'two'],
...                    'bar': ['A', 'B', 'C', 'D', 'E', 'F'],
...                    'baz': [1, 2, 3, 4, 5, 6],
...                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df
# Out:
#      foo bar  baz zoo
# 0    one   A    1   x
# 1    one   B    2   y
# 2    one   C    3   z
# 3    two   D    4   q
# 4  three   E    5   w
# 5    two   F    6   t

# %%
>>> df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar      A    B    C    D    E    F
# foo
# one    1.0  2.0  3.0  NaN  NaN  NaN
# three  NaN  NaN  NaN  NaN  5.0  NaN
# two    NaN  NaN  NaN  4.0  NaN  6.0
