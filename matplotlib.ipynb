# %%
import pandas as pd
df = pd.read_excel(r"E:\stat.xlsx","Sheet1")
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-08         28.0        9.0   sunny
# 2 2017-01-04         32.0        7.0    snow
# 3 2017-01-03         34.0        8.0   rainy
# 4 2017-01-02         40.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07         60.0       11.0   sunny
# 7        NaT          NaN        NaN

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_excel(r"E:\stat.xlsx","Sheet1",parse_dates=["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-08         28.0        9.0   sunny
# 2 2017-01-04         32.0        7.0    snow
# 3 2017-01-03         34.0        8.0   rainy
# 4 2017-01-02         40.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07         60.0       11.0   sunny
# 7        NaT          NaN        NaN

# %%
import pandas as pd
df =pd.read_excel(r"E:\stat.xlsx","Sheet1")
df.set_index("day",inplace =True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-08         28.0        9.0   sunny
# 2017-01-04         32.0        7.0    snow
# 2017-01-03         34.0        8.0   rainy
# 2017-01-02         40.0       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07         60.0       11.0   sunny
# NaT                 NaN        NaN

# %%
df = pd.read_excel(r"E:\newfile py\stat.xlsx","Sheet1",na_values = "mavailable")
df
# Out:
#          day  temperature windspeed   event
# 0 2017-01-01         32.0     6 mph   rainy
# 1 2017-01-02      -9999.0     9 mph     NaN
# 2 2017-01-03         32.0     7 mph    snow
# 3 2017-01-04         34.0     8 mph   rainy
# 4 2017-01-05      -8888.0    12 mph   sunny
# 5 2017-01-06         20.0    13 mph  cloudy
# 6 2017-01-07          NaN    11 mph   sunny
# 7        NaT          NaN       NaN

# %%
df=df.fillna(0)
df
# Out:
#                      temperature  windspeed   event
# day
# 2017-01-01 00:00:00         32.0        6.0   rainy
# 2017-01-08 00:00:00         28.0        9.0   sunny
# 2017-01-04 00:00:00         32.0        7.0    snow
# 2017-01-03 00:00:00         34.0        8.0   rainy
# 2017-01-02 00:00:00         40.0       12.0   sunny
# 2017-01-06 00:00:00         20.0       13.0  cloudy
# 2017-01-07 00:00:00         60.0       11.0   sunny
# 0                            0.0        0.0

# %%
new_df = df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'no value'
})
new_df
# Out:
#                    day    temperature      windspeed          event
# 0  2017-01-01 00:00:00           32.0            6.0          rainy
# 1  2017-01-02 00:00:00           28.0            9.0  not available
# 2  2017-01-03 00:00:00           32.0            7.0           snow
# 3  2017-01-04 00:00:00           34.0            8.0          rainy
# 4  2017-01-05 00:00:00  not available           12.0          sunny
# 5  2017-01-06 00:00:00           20.0           13.0         cloudy
# 6  2017-01-07 00:00:00  not available           11.0          sunny
# 7        not available  not available  not available

# %%
import pandas as pd
df = pd.read_csv(r"E:\stat.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
df.fillna(method = "ffill")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11840\3045715491.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill")
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-08         28.0        9.0   sunny
# 2017-01-04         32.0        7.0    snow
# 2017-01-03         34.0        8.0   rainy
# 2017-01-02         40.0       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07         60.0       11.0   sunny
# NaT                60.0       11.0

# %%
df.fillna(0)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-08         28.0        9.0   sunny
# 2017-01-04         32.0        7.0    snow
# 2017-01-03         34.0        8.0   rainy
# 2017-01-02         40.0       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07         60.0       11.0   sunny
# NaT                 0.0        0.0

# %%
df.fillna(0)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-08         28.0        9.0   sunny
# 2017-01-04         32.0        7.0    snow
# 2017-01-03         34.0        8.0   rainy
# 2017-01-02         40.0       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07         60.0       11.0   sunny
# NaT                 0.0        0.0

# %%
df = df.fillna(0)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-08         28.0        9.0   sunny
# 2017-01-04         32.0        7.0    snow
# 2017-01-03         34.0        8.0   rainy
# 2017-01-02         40.0       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07         60.0       11.0   sunny
# NaT                 0.0        0.0

# %%
df = df.fillna(0,axis="columns")
df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0   rainy
# 2017-01-08        28.0       9.0   sunny
# 2017-01-04        32.0       7.0    snow
# 2017-01-03        34.0       8.0   rainy
# 2017-01-02        40.0      12.0   sunny
# 2017-01-06        20.0      13.0  cloudy
# 2017-01-07        60.0      11.0   sunny
# NaT                  0         0

# %% [raw]
# df = df.fillna({"day":"not_specified"})
# df

# %%
df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0   rainy
# 2017-01-08        28.0       9.0   sunny
# 2017-01-04        32.0       7.0    snow
# 2017-01-03        34.0       8.0   rainy
# 2017-01-02        40.0      12.0   sunny
# 2017-01-06        20.0      13.0  cloudy
# 2017-01-07        60.0      11.0   sunny
# NaT                  0         0

# %%
df = pd.read_csv(r"E:\stat.csv",na_values="n_values",parse_dates =['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-08         28.0        9.0   sunny
# 2 2017-01-04         32.0        7.0    snow
# 3 2017-01-03         34.0        8.0   rainy
# 4 2017-01-02         40.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07         60.0       11.0   sunny
# 7        NaT          NaN        NaN

# %%
df = df.fillna(0)
df
# Out:
#                    day  temperature  windspeed   event
# 0  2017-01-01 00:00:00         32.0        6.0   rainy
# 1  2017-01-08 00:00:00         28.0        9.0   sunny
# 2  2017-01-04 00:00:00         32.0        7.0    snow
# 3  2017-01-03 00:00:00         34.0        8.0   rainy
# 4  2017-01-02 00:00:00         40.0       12.0   sunny
# 5  2017-01-06 00:00:00         20.0       13.0  cloudy
# 6  2017-01-07 00:00:00         60.0       11.0   sunny
# 7                    0          0.0        0.0

# %%
df.set_index("day",inplace=True)
df
# Out:
#                      temperature  windspeed   event
# day
# 2017-01-01 00:00:00         32.0        6.0   rainy
# 2017-01-08 00:00:00         28.0        9.0   sunny
# 2017-01-04 00:00:00         32.0        7.0    snow
# 2017-01-03 00:00:00         34.0        8.0   rainy
# 2017-01-02 00:00:00         40.0       12.0   sunny
# 2017-01-06 00:00:00         20.0       13.0  cloudy
# 2017-01-07 00:00:00         60.0       11.0   sunny
# 0                            0.0        0.0

# %%
df
# Out:
#                      temperature  windspeed   event
# day
# 2017-01-01 00:00:00         32.0        6.0   rainy
# 2017-01-08 00:00:00         28.0        9.0   sunny
# 2017-01-04 00:00:00         32.0        7.0    snow
# 2017-01-03 00:00:00         34.0        8.0   rainy
# 2017-01-02 00:00:00         40.0       12.0   sunny
# 2017-01-06 00:00:00         20.0       13.0  cloudy
# 2017-01-07 00:00:00         60.0       11.0   sunny
# 0                            0.0        0.0

# %%
df.interpolate(method = "pad")
df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11840\691838099.py:1: FutureWarning: DataFrame.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.interpolate(method = "pad")
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-08         28.0        9.0   sunny
# 2 2017-01-04         32.0        7.0    snow
# 3 2017-01-03         34.0        8.0   rainy
# 4 2017-01-02         40.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07         60.0       11.0   sunny
# 7        NaT          NaN        NaN

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df = df.dropna(axis='index',thresh = 2)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02      -9999.0        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05      -9999.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny

# %%
dt = pd.date_range('2017-01-01','2017-01-08')
dt
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np
df = pd.read_excel(r'C:\Users\Administrator\OneDrive\Desktop\stat.xlsx','Sheet1')
df
# Out:
#          day  temperature windspeed   event
# 0 2017-01-01         32.0     6 mph   rainy
# 1 2017-01-02      -9999.0     9 mph     NaN
# 2 2017-01-03         32.0     7 mph    snow
# 3 2017-01-04         34.0     8 mph   rainy
# 4 2017-01-05      -8888.0    12 mph   sunny
# 5 2017-01-06         20.0    13 mph  cloudy
# 6 2017-01-07          NaN    11 mph   sunny
# 7        NaT          NaN       NaN

# %%
new_df = df.replace(-9999.0,np.nan)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05      -8888.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny
# 7        NaT          NaN        NaN

# %%
df = df.dropna(thresh =2)

df = df.replace([-9999.0,-8888],np.nan)
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05          NaN       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05          NaN       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny

# %%
df.set_index('day',inplace = True)

df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0   rainy
# 2017-01-02          NaN        9.0     NaN
# 2017-01-03         32.0        7.0    snow
# 2017-01-04         34.0        8.0   rainy
# 2017-01-05          NaN       12.0   sunny
# 2017-01-06         20.0       13.0  cloudy
# 2017-01-07          NaN       11.0   sunny

# %%
df.dropna(thresh =3)
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05          NaN       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny

# %%
new = df.replace({
    -9999.0:np.nan,
    'snow':'sunny'
})
new
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0   sunny
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05      -8888.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny
# 7        NaT          NaN        NaN

# %%
new_df = df.replace({
    "temperature" : -8888.0,
    "windspeed" : 12.0
},np.nan)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02      -9999.0        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05          NaN        NaN   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny
# 7        NaT          NaN        NaN

# %%
n = df.replace({
    -9999.0:np.nan
    
})
n
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0   rainy
# 1 2017-01-02          NaN        9.0     NaN
# 2 2017-01-03         32.0        7.0    snow
# 3 2017-01-04         34.0        8.0   rainy
# 4 2017-01-05      -8888.0       12.0   sunny
# 5 2017-01-06         20.0       13.0  cloudy
# 6 2017-01-07          NaN       11.0   sunny
# 7        NaT          NaN        NaN

# %%
df = df.replace({
    'temperature':"[A-Za-z]",
    'windspeed':'[A-Za-z]'},'',regex=True)
df
# Out:
#          day  temperature windspeed   event
# 0 2017-01-01         32.0        6    rainy
# 1 2017-01-02      -9999.0        9      NaN
# 2 2017-01-03         32.0        7     snow
# 3 2017-01-04         34.0        8    rainy
# 4 2017-01-05      -8888.0       12    sunny
# 5 2017-01-06         20.0       13   cloudy
# 6 2017-01-07          NaN       11    sunny
# 7        NaT          NaN       NaN

# %%
df = pd.DataFrame({
    'student': ['amit','saha','rob','joe','biden'],
    'score':['good','very good','not good','excellent','fail']
})
df
# Out:
#   student      score
# 0    amit       good
# 1    saha  very good
# 2     rob   not good
# 3     joe  excellent
# 4   biden       fail

# %%
df = df.replace(['good','very good','not good','excellent','fail'],[1,2,3,4,5])

df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10208\4088853240.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(['good','very good','not good','excellent','fail'],[1,2,3,4,5])
#   student  score
# 0    amit      1
# 1    saha      2
# 2     rob      3
# 3     joe      4
# 4   biden      5

# %%
import pandas as pd
df =pd.read_excel(r'E:\newfile py\stat.xlsx','Sheet1')
df
# Out:
#          day     city  temperature windspeed   event
# 0 2017-01-01  NewYork         32.0         6   rainy
# 1 2017-01-02  NewYork      -9999.0         9     NaN
# 2 2017-01-03   mumbai         32.0         7    snow
# 3 2017-01-04  NewYork         34.0         8   rainy
# 4 2017-01-05   mumbai      -8888.0        12   sunny
# 5 2017-01-06   mumbai         20.0        13  cloudy
# 6 2017-01-07    dhaka          NaN        11   sunny
# 7        NaT      NaN          NaN               NaN

# %%
g= g.groupby('city')
g

# %%
for city, cdf in g:
    print(city)
    print(cdf)
# Out:
# NewYork
#          day     city  temperature windspeed  event
# 0 2017-01-01  NewYork         32.0        6   rainy
# 1 2017-01-02  NewYork      -9999.0        9     NaN
# 3 2017-01-04  NewYork         34.0        8   rainy
# dhaka
#          day   city  temperature windspeed  event
# 6 2017-01-07  dhaka          NaN       11   sunny
# mumbai
#          day    city  temperature windspeed   event
# 2 2017-01-03  mumbai         32.0        7     snow
# 4 2017-01-05  mumbai      -8888.0       12    sunny
# 5 2017-01-06  mumbai         20.0       13   cloudy

# %%
g.get_group('dhaka')
# Out:
#          day   city  temperature windspeed  event
# 6 2017-01-07  dhaka          NaN       11   sunny

# %%
g.get_group('NewYork')
# Out:
#          day     city  temperature windspeed  event
# 0 2017-01-01  NewYork         32.0        6   rainy
# 1 2017-01-02  NewYork      -9999.0        9     NaN
# 3 2017-01-04  NewYork         34.0        8   rainy

# %%
# Assuming your DataFrame is named 'df'
print(df['windspeed'].dtypes)
# Out:
# float64

# %%
g.max('windspeed')
# Out:
#          temperature
# city
# NewYork         34.0
# dhaka            NaN
# mumbai          32.0

# %%
# Assuming your DataFrame is named 'df' and the column you want to convert is named 'column_name'
df['windspeed'] = pd.to_numeric(df['windspeed'], errors='coerce')

# Now the 'column_name' will be converted to float datatype

# %%
df
# Out:
#          day     city  temperature  windspeed   event
# 0 2017-01-01  NewYork         32.0        6.0   rainy
# 1 2017-01-02  NewYork      -9999.0        9.0     NaN
# 2 2017-01-03   mumbai         32.0        7.0    snow
# 3 2017-01-04  NewYork         34.0        8.0   rainy
# 4 2017-01-05   mumbai      -8888.0       12.0   sunny
# 5 2017-01-06   mumbai         20.0       13.0  cloudy
# 6 2017-01-07    dhaka          NaN       11.0   sunny
# 7        NaT      NaN          NaN        NaN     NaN

# %%
g.describe()
# Out:
#           day                                                                 \
#         count                 mean                  min                  25%
# city
# NewYork     3  2017-01-02 08:00:00  2017-01-01 00:00:00  2017-01-01 12:00:00
# dhaka       1  2017-01-07 00:00:00  2017-01-07 00:00:00  2017-01-07 00:00:00
# mumbai      3  2017-01-04 16:00:00  2017-01-03 00:00:00  2017-01-04 00:00:00
#
#                                                                              \
#                          50%                  75%                  max  std
# city
# NewYork  2017-01-02 00:00:00  2017-01-03 00:00:00  2017-01-04 00:00:00  NaN
# dhaka    2017-01-07 00:00:00  2017-01-07 00:00:00  2017-01-07 00:00:00  NaN
# mumbai   2017-01-05 00:00:00  2017-01-05 12:00:00  2017-01-06 00:00:00  NaN
#
#         temperature                                                 \
#               count         mean     min     25%   50%   75%   max
# city
# ...

# %%
g.max('temperat')
# Out:
#          temperature
# city
# NewYork         34.0
# dhaka            NaN
# mumbai          32.0

# %%
# %matplotlib inline
g.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# city
# NewYork    Axes(0.125,0.11;0.775x0.77)
# dhaka      Axes(0.125,0.11;0.775x0.77)
# mumbai     Axes(0.125,0.11;0.775x0.77)
# dtype: object
